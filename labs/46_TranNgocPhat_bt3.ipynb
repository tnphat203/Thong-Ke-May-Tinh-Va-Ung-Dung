# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Lab 03 - Bài tập

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
arr = np.random.randint(0, 1000, size=100)
arr
# Out:
# array([ 55, 942, 847, 236, 379, 287, 142, 807, 483,  12, 347, 247, 385,
#        901, 398, 755, 964, 916,  54, 848, 231, 127, 239,  42, 346, 943,
#        655, 460, 202, 757, 185, 158,  43, 791, 469, 217, 568,  18, 955,
#        211,  51, 887, 721, 214, 528, 237, 126, 700, 771, 583, 717, 603,
#        865,  75, 412, 346, 786, 629, 227, 932, 707, 796, 880, 793,  50,
#        946, 169, 985, 367, 194, 196,  43, 979, 817, 783, 655, 443, 242,
#        635, 321, 920, 879, 667, 871, 989, 425, 221, 716, 837, 160, 509,
#        722, 356, 935, 882,  11, 862, 884, 441, 779])

# %%
#10 phần tử đầu tiên
print("10 phần tử đầu tiên: ", arr[:10])
#5 phần tử cuối cùng
print("5 phần tử cuối cùng là: ", arr[-5:])
#Các phần tử chia hết cho 5 và lớn hơn 100
print("Các phần tử chia hết cho 5 và lớn hơn 100: ", arr[(arr % 5 == 0 ) & (arr > 100)])
# Out:
# 10 phần tử đầu tiên:  [ 55 942 847 236 379 287 142 807 483  12]
# 5 phần tử cuối cùng là:  [ 11 862 884 441 779]
# Các phần tử chia hết cho 5 và lớn hơn 100:  [385 755 655 460 185 955 700 865 880 985 655 635 920 425 160 935]

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
print(f"Số phần tử có giá trị nhỏ hơn 100: {len(arr[arr < 100])}")
print(f"Các phần tử đó là: {arr[arr < 100]}")
# Out:
# Số phần tử có giá trị nhỏ hơn 100: 11
# Các phần tử đó là: [55 12 54 42 43 18 51 75 50 43 11]

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
print(f"Tổng  mảng là: {np.sum(arr)}")
print(f"Giá trị trung bình là: {np.mean(arr)}")
print(f"Giá trị trung vị là: {np.median(arr)}")
print(f"Q1 là: {np.quantile(arr, 0.25)}")
print(f"Q2 là: {np.quantile(arr, 0.5)}")
print(f"Q3 là: {np.quantile(arr, 0.75)}")
print(f"Phân vị 20 là: {np.quantile(arr, 0.2)}")
# Out:
# Tổng  mảng là: 52099
# Giá trị trung bình là: 520.99
# Giá trị trung vị là: 518.5
# Q1 là: 225.5
# Q2 là: 518.5
# Q3 là: 809.5
# Phân vị 20 là: 200.8

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for i in range(5):
    print(f"Các phần tử lấy ngẫu nhiên lần {i + 1}: ")
    print(np.random.choice(arr, 10))
# Out:
# các phần tử lấy ngẫu nhiên lần 1:
# [979 943 509 142 901 655 721 214 942 469]
# các phần tử lấy ngẫu nhiên lần 2:
# [791 667 943 882 127  43 346 398 142 443]
# các phần tử lấy ngẫu nhiên lần 3:
# [817 236 247 887 655 716 142 196  75 443]
# các phần tử lấy ngẫu nhiên lần 4:
# [932 211 242 441 807 385 865  42  54 796]
# các phần tử lấy ngẫu nhiên lần 5:
# [ 11 239 356 169 779  43 793 783 655 848]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
print(f"Phần tử xuất hiện nhiều nhất là: {np.argmax(np.bincount(arr))}")
# Out:
# Phần tử xuất hiện nhiều nhất là: 43

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# Viết mã để vẽ các đồ thị sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
# Your code here
plt.plot([1,6,4],[4,10,1])
plt.title("Sample graph!")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
# Your code here
plt.plot([10, 20, 40],[50, 10, 30], color = "blue", label = "line 2")
plt.plot([10, 20, 40],[30, 40, 10], color = "red", label = "line 1")
plt.legend()
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
# Your code here
plt.plot([1, 4, 5, 7, 7], [2, 6, 4, 7, 3], marker = "o", markeredgecolor = "red", markerfacecolor = "red")
plt.show()

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
x = np.linspace(0, 6 , 60)
sinx = np.sin(x)
cosx = np.cos(x)
plt.plot(x, sinx, label = "sin(x)")
plt.plot(x, cosx, label = "cos(x)", ls = "--")
plt.grid()
plt.title("Đồ thị Sin(x) và Cos(x)")
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
x = np.linspace(0, 6, 60)
sinx = np.sin(x)
cosx = np.cos(x)

plt.title("Đồ thị sin(x) và cos(x)")

plt.subplot(2, 1, 1)
plt.plot(x, sinx, label = "sin(x)", color = "blue")
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, cosx, label = "cos(x)", color = "red")
plt.legend()

plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
# Your code here
x = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
y = [25, 20, 10, 8, 7, 6]
plt.bar(x, y)
plt.title("Mức độ phổ biến của các ngôn ngữ lập trình")
plt.xlabel("Programing Language")
plt.ylabel("Popularity")
plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
# Your code here
data = {
    "Python": 20.8,
    "Java": 35.28,
    "C++": 15.40,
    "C#": 4.89,
    "JavaScript": 10.3,
    "PHP": 13.42
}

explode = [0.1 if label == "Java" else 0 for label in data.keys()]
plt.pie(data.values(), labels=data.keys(), autopct='%1.1f%%', explode=explode)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
# Your code here
x = np.random.normal(size = 10000)
plt.hist(x, bins = 10)
plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
# Your code here
plt.boxplot(x)
plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
fig, axs = plt.subplots(2, 1)

axs[0].set_title("Histogram")
axs[0].hist(x, bins = 100, color = "red")
axs[0].set_ylabel("Mật độ")

axs[1].set_title("Boxplot")
axs[1].boxplot(x, vert=False)

# Điều chỉnh khoảng cách giữa các subplot
plt.subplots_adjust(hspace=0.5)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn là một thư viện hỗ trợ trực quan hóa được viết dựa trên thư viện `matplotlib`. Trong bài tập này, bạn hãy tự tìm hiểu thư viện `seaborn` và trực quan hóa dữ liệu tiền tip tại một nhà hàng.
#
# Bạn có thể dùng đoạn mã sau để đọc dữ liệu có sẵn trong `seaborn`
#
# ```python
# import seaborn as sns
#
# df = sns.load_dataset("tips")
# df.head()
# ```
# Hoặc bạn có thể đọc dữ liệu chứa trong file `tips.csv` chứa thông tin tiền tip của khách hàng tại một nhà hàng. Dữ liệu có các thông tin sau:
#
# - `total_bill`: tổng hoá đơn (USD)
# - `tip`: tiền tip/ tiền boa (USD)
# - `sex`: giới tính người thanh toán hóa đơn
# - `smoker`: có hút thuốc hay không
# - `day`: ngày trong tuần
# - `time`: thời gian dùng bữa(buổi sáng, buổi trưa, buổi tối)
# - `size`: số lượng người tham gia
#
# Bạn hãy lựa chọn loại đồ thị phù hợp để trả lời những câu hỏi sau:

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 1. Vẽ đồ thị thể hiện tổng tiền tip theo ngày

# %%
TotalBillByDay = df.groupby("day").agg({
    "total_bill" : "sum"
})
sns.barplot(x="day", y="total_bill", data=TotalBillByDay)
# Out:
# C:\Users\TranNgocPhat\AppData\Local\Temp\ipykernel_19396\1416758956.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   TotalBillByDay = df.groupby("day").agg({
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### 2. Vẽ đồ thị thể hiện tổng tiền tip theo thời gian dùng bữa (time)

# %%
TotalBillByTime = df.groupby("time").agg({
    "total_bill" : "sum"
})
sns.barplot(x="time", y="total_bill", data=TotalBillByTime)
# Out:
# C:\Users\TranNgocPhat\AppData\Local\Temp\ipykernel_19396\2701741326.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   TotalBillByTime = df.groupby("time").agg({
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ### 3. Vẽ đồ thị histogram của tổng hoá đơn

# %%
sns.histplot(x = "total_bill",data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### 4. Vẽ đồ thị boxplot của tổng hoá đơn

# %%
sns.boxplot(x = "total_bill", data = df)
# Out:
# c:\Users\TranNgocPhat\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ### 5. Vẽ đồ thị boxplot so sánh tổng hóa đơn giữa các ngày trong tuần

# %%
sns.boxplot(x='day', y='total_bill', data=df)
# Out:
# c:\Users\TranNgocPhat\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### 6. Vẽ đồ thị để kiểm tra sự liên quan giữa tổng hoá đơn và tiền tip. (`scatter plot`)

# %%
sns.scatterplot(data = df, x = "total_bill", y = "tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 7. Tìm hiểu và sử dụng hàm `jointplot` trong seaborn để khảo sát quan hệ giữa hai thuộc tính `total_bill` và `tip`. Theo bạn hai thuộc tính này có tương quan với nhau hay không?

# %%
sns.jointplot(data = df, x = "total_bill", y = "tip")

# %% [markdown]
# **Dựa vào biểu đồ jointplot trên ta nhận có sự tương quan tuyến tính giữa thuộc tính "total bill" và "tip"**

# %% [markdown]
# ### 8. Tìm hiểu và sử dụng hàm `pairplot` trong seaborn để trực quan bộ dữ liệu. Theo bạn, trong bộ dữ liệu có những thuộc tính nào liên quan với nhau không?

# %%
sns.pairplot(data = df)

# %% [markdown]
# **Dựa vào biểu đồ pairplot trên ta nhận thấy có có sự liên quan giữa 2 thuộc tính "total_bill" và "tip"**

# %% [markdown]
# ### 9. Vẽ hai đồ thị histogram cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
sns.histplot(data=df, x="total_bill", hue="time", bins=10, kde=True)
# Out:
# c:\Users\TranNgocPhat\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\TranNgocPhat\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### 10. Vẽ hai đồ thị boxplot cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
sns.boxplot(x="time", y="total_bill", data=df)
# Out:
# c:\Users\TranNgocPhat\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ---
