# %% [markdown]
# # Bài Tập

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import t

# %% [markdown]
# ### Bài 1: Tạo quần thể mô phỏng
#
# Bạn hãy tạo một mẫu gồm 10000 phần tử mô phỏng chiều cao của nam thanh niên có giá trị từ 120cm - 200cm. Bạn hãy lưu kết quả vào biến **POP**.
#
# Tính:
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
#
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
#
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
#
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.

# %%
POP = np.random.normal(120, 200, 10000)

# %%
# a
chieuCao_mean = np.mean(POP)
chieuCao_std = np.std(POP)

print("Chiều cao trung bình: ", chieuCao_mean)
print("Độ lệch chuẩn: ", chieuCao_std)
# Out:
# Chiều cao trung bình:  120.1489373603603
# Độ lệch chuẩn:  198.33372859142034

# %%
# b
nguoiCao = POP[POP >= 180]
tyLeNguoiCao = len(nguoiCao) / len(POP) * 100
print("Tỷ lệ người cao: ", tyLeNguoiCao)
# Out:
# Tỷ lệ người cao:  38.01

# %%
# c
plt.hist(POP, bins=100)
plt.title("Chiều cao của quần thể")
plt.xlabel("Chiều cao")
plt.ylabel("Số người")
plt.show()

# %% [markdown]
# Đồ thị trên có phân phối chuẩn

# %%
# d
data = np.linspace(POP.min(), POP.max(), 100)
plt.plot(data, norm.pdf(data, chieuCao_mean, chieuCao_std))
plt.title("Phân phối chuẩn")
plt.xlabel("Chiều cao")
plt.ylabel("Xác suất")
plt.show()

# %% [markdown]
# ### Bài 2: Lấy mẫu cỡ 20
#
# Bạn hãy lấy một mẫu kích thước 20 phần từ. Tính:
#
# a. Trung bình mẫu, và độ lệch chuẩn của mẫu
#
# b. Tỷ lệ người cao của mẫu
#
# c. Vẽ histogram của mẫu
#
# d. Thử vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu. Bạn có nhận xét gì không?

# %%
sample_bai2 = np.random.choice(POP, 20)

# %%
# a
sample_bai2_mean = np.mean(sample_bai2)
sample_bai2_std = np.std(sample_bai2)

print("Chiều cao trung bình: ", sample_bai2_mean)
print("Độ lệch chuẩn: ", sample_bai2_std)
# Out:
# Chiều cao trung bình:  90.38770582693084
# Độ lệch chuẩn:  199.10563353306972

# %%
# b
sample_nguoiCao = sample_bai2[sample_bai2 >= 180]
sample_tyLeNguoiCao = len(sample_nguoiCao) / len(sample_bai2) * 100
print("Tỷ lệ người cao: ", sample_tyLeNguoiCao)
# Out:
# Tỷ lệ người cao:  30.0

# %%
# c
plt.hist(sample_bai2, bins=10)
plt.title("Chiều cao của quần thể")
plt.xlabel("Chiều cao")
plt.ylabel("Số người")
plt.show()

# %%
# d
data = np.linspace(sample_bai2.min(), sample_bai2.max(), 100)
plt.plot(data, norm.pdf(data, sample_bai2_mean, sample_bai2_std))
plt.title("Phân phối chuẩn")
plt.xlabel("Chiều cao")
plt.ylabel("Xác suất")
plt.show()

# %% [markdown]
# ### Bài 3: Lấy mẫu cỡ 100
#
# Lặp lại thí nghiệm bài 2 với cỡ mẫu là 100

# %%
sample_bai3 = np.random.choice(POP, 100)

# %%
# a
sample_bai3_mean = np.mean(sample_bai3)
sample_bai3_std = np.std(sample_bai3)

print("Chiều cao trung bình: ", sample_bai3_mean)
print("Độ lệch chuẩn: ", sample_bai3_std)
# Out:
# Chiều cao trung bình:  109.30338641853858
# Độ lệch chuẩn:  198.97650858353865

# %%
# b
sample_nguoiCao = sample_bai3[sample_bai3 >= 180]
sample_tyLeNguoiCao = len(sample_nguoiCao) / len(sample_bai3) * 100
print("Tỷ lệ người cao: ", sample_tyLeNguoiCao)
# Out:
# Tỷ lệ người cao:  36.0

# %%
# c
plt.hist(sample_bai3, bins=100)
plt.title("Chiều cao của quần thể")
plt.xlabel("Chiều cao")
plt.ylabel("Số người")
plt.show()

# %%
# d
data = np.linspace(sample_bai3.min(), sample_bai3.max(), 100)
plt.plot(data, norm.pdf(data, sample_bai3_mean, sample_bai3_std))
plt.title("Phân phối chuẩn")
plt.xlabel("Chiều cao")
plt.ylabel("Xác suất")
plt.show()

# %% [markdown]
# ### Bài 4: Khảo sát phân phối của trung bình mẫu
#
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
#
# Gợi ý: tạo một danh sách rỗng để chứa các trung bình mẫu tính được, sử dụng hàm append() để thêm giá trị trung bình vào danh sách sau mỗi lần tính.

# %%
# a
mean_sample_bai4_a = []
for i in range(100):
    tmp_sample = np.random.choice(POP, 20)
    mean_sample_bai4_a.append(np.mean(tmp_sample))
plt.hist(mean_sample_bai4_a, bins=10)
plt.title("Trung bình mẫu")
plt.xlabel("Trung bình")
plt.ylabel("Số lần")
plt.show()

# %%
# b
mean_sample_bai4_b = []
for i in range(100):
    tmp_sample = np.random.choice(POP, 100)
    mean_sample_bai4_b.append(np.mean(tmp_sample))
plt.hist(mean_sample_bai4_b, bins=10)
plt.title("Trung bình mẫu")
plt.xlabel("Trung bình")
plt.ylabel("Số lần")
plt.show()

# %%
plt.hist(mean_sample_bai4_a, bins=10)
plt.hist(mean_sample_bai4_b, bins=10)
plt.title("Trung bình mẫu")
plt.xlabel("Trung bình")
plt.ylabel("Số lần")
plt.show()

# %% [markdown]
# Hai đồ thị đều phân phối chuẩn

# %% [markdown]
# ### Bài 5: Khảo sát tỷ lệ mẫu
#
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
#
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu

# %%
# a
mean_sample_bai5_a = []
for i in range(1000):
    tmp_sample = np.random.choice(POP, 100)
    mean_sample_bai5_a.append(np.mean(tmp_sample))

plt.hist(mean_sample_bai5_a, bins=10)
plt.title("Trung bình mẫu")
plt.xlabel("Trung bình")
plt.ylabel("Số lần")
plt.show()

# %%
# b
mean_sample_bai5_b = []
for i in range(1000):
    tmp_sample = np.random.choice(POP, 500)
    mean_sample_bai5_b.append(np.mean(tmp_sample))

plt.hist(mean_sample_bai5_b, bins=10)
plt.title("Trung bình mẫu")
plt.xlabel("Trung bình")
plt.ylabel("Số lần")
plt.show()

# %% [markdown]
# ### Bài 6: Khảo sát phương sai mẫu
#
# Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram đại lượng phương sai của các mẫu (Phương sai bằng bình phương độ lệch chuẩn)

# %%
sample_bai6 = []
for i in range(1000):
    tmp_sample = np.random.choice(POP, 100)
    sample_bai6.append(np.std(tmp_sample)**2)

plt.hist(sample_bai6, bins=10)
plt.title("Phương sai mẫu")
plt.xlabel("Phương sai")
plt.ylabel("Số lần")
plt.show()

# %% [markdown]
# ### Bài 7:  Bài Tập Ước Lượng
#
# Khảo sát cân nặng (kg) của gà khi xuất chuồng, người ta cân một số con và có kết quả như sau:
#
# > 2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8
#
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của  khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
#
# a, Biết $\sigma = 0.3$
#
# b, Không biết $\sigma$

# %%
# a
weights = np.array([2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8])
sample_mean = np.mean(weights)
sigma = 0.3
confidence_level = 0.95

z = norm.ppf((1 + confidence_level) / 2)

margin_of_error = z * sigma / np.sqrt(len(weights))

confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

confidence_interval
# Out:
# (1.7373369348793277, 2.1293297317873385)

# %%
# b
sample_std = np.std(weights, ddof=1)
sample_size = len(weights)
t_critical = t.ppf((1 + confidence_level) / 2, df=sample_size - 1)

margin_of_error = t_critical * sample_std / np.sqrt(sample_size)
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

confidence_interval
# Out:
# (1.7373606652839864, 2.12930600138268)
